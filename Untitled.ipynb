# %%
import pandas as pd

# %%
df_1 = pd.read_parquet("~/temp/movie/dt=20210101")
df_2 = pd.read_parquet("~/temp/movie")

df.to_parquet('~/temp?
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_1 = pd.read_parquet("~/temp/movie/dt=20210101")
#       2 df_2 = pd.read_parquet("~/temp/movie")
#       4 get_ipython().run_line_magic('pinfo', 'temp')
#
# File ~/code/movie/.venv/lib/python3.10/site-packages/pandas/io/parquet.py:651, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     498 @doc(storage_options=_shared_docs["storage_options"])
#     499 def read_parquet(
#     500     path: FilePath | ReadBuffer[bytes],
#    (...)
#     508     **kwargs,
#     509 ) -> DataFrame:
#     510     """
#     511     Load a parquet object from the file path, returning a DataFrame.
#     512
#    (...)
#     648     1    4    9
#     649     """
# --> 651     impl = get_engine(engine)
# ...

# %%
df_2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_2.head()
#
# NameError: name 'df_2' is not defined
