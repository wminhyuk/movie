# %%
import pandas as pd
PATH = "~/data/movies/dailyboxoffice/dt=20240101"
df = pd.read_parquet(PATH)

# %%
def fillna_meta(previous_df: pd.DataFrame, current_df: pd.DataFrame) -> pd.DataFrame:
    if previous_df is None:
        return current_df[["movieCd", "multiMovieYn", "repNationCd"]]
    
    # movieCd 기준으로 outer join
    merged_df = previous_df.merge(current_df, on="movieCd", how="outer", suffixes=("_A", "_B"))
    print(merged_df)

    # NaN 값 대체 (A 값 우선, 없으면 B 값 사용)
    merged_df["multiMovieYn"] = merged_df["multiMovieYn_A"].combine_first(merged_df["multiMovieYn_B"])
    merged_df["repNationCd"] = merged_df["repNationCd_A"].combine_first(merged_df["repNationCd_B"])

    # 불필요한 컬럼 제거
    meta_df = merged_df[["movieCd", "multiMovieYn", "repNationCd"]]
    
    return meta_df
fillna_meta
# Out:
# <function __main__.fillna_meta(previous_df: pandas.core.frame.DataFrame, current_df: pandas.core.frame.DataFrame) -> pandas.core.frame.DataFrame>

# %%
df.drop(columns=['rankInten'])
# Out:
#     rnum  rank rankOldAndNew   movieCd                               movieNm  \
# 0      1     1           OLD  20203702                            노량: 죽음의 바다
# 1      2     2           OLD  20212866                                 서울의 봄
# 2      3     3           OLD  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~
# 3      4     4           OLD  20235735                          아쿠아맨과 로스트 킹덤
# 4      5     5           OLD  20235596                            트롤: 밴드 투게더
# 5      6     6           OLD  20234673                      뽀로로 극장판 슈퍼스타 대모험
# 6      7     7           OLD  20235290                             도티와 영원의 탑
# 7      8     8           OLD  20234114                                    괴물
# 8      9     9           OLD  20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!
# 9     10    10           OLD  20235980                             말하고 싶은 비밀
# 10     1     1           OLD  20203702                            노량: 죽음의 바다
# 11     2     2           OLD  20212866                                 서울의 봄
# 12     3     3           OLD  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~
# 13     4     4           OLD  20235735                          아쿠아맨과 로스트 킹덤
# 14     5     5           OLD  20235596                            트롤: 밴드 투게더
# 15     6     6           OLD  20234673                      뽀로로 극장판 슈퍼스타 대모험
# 16     7     7           OLD  20235290                             도티와 영원의 탑
# 17     8     8           OLD  20235980                             말하고 싶은 비밀
# 18     9     9           OLD  20190324                                3일의 휴가
# 19    10    10           OLD  20235098                                  나폴레옹
# 20     1     1           OLD  20234114                                    괴물
# 21     2     2           OLD  20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!
# 22     3     3           OLD  20236080                         류이치 사카모토: 오퍼스
# 23     4     4           OLD  20233299                                  크레센도
# 24     5     5           OLD  20235923                            사랑은 낙엽을 타고
# 25     6     6           OLD  20235693                             리빙: 어떤 인생
# 26     7     7           OLD  20234664                        그대들은 어떻게 살 것인가
# 27     8     8           OLD  20124722                             피아니스트의 전설
# 28     9     8           NEW  20236533                                립세의 사계
# 29    10    10           OLD  19860125                                  쿼바디스
# 30     1     1           OLD  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~
# 31     2     2           OLD  20235735                          아쿠아맨과 로스트 킹덤
# 32     3     3           OLD  20235596                            트롤: 밴드 투게더
# 33     4     4           OLD  20234114                                    괴물
# 34     5     5           OLD  20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!
# 35     6     6           OLD  20235980                             말하고 싶은 비밀
# 36     7     7           OLD  20236080                         류이치 사카모토: 오퍼스
# 37     8     8           OLD  20233299                                  크레센도
# 38     9     9           OLD  20235923                            사랑은 낙엽을 타고
# 42  2023-12-13   113680587         2.0     2278496          2.0    3046919883
# 43  2023-12-27   100024717         1.7   -13487835        -11.9     488186693
# 44  2023-12-06    28109697         0.5    -5429437        -16.2    4863180386
# 45  2023-11-29     1903007         0.0     -409621        -17.7    3740536035
# 46  2023-10-25     2625839         0.0    -3233861        -55.2     330224803
# 47  2023-12-06     1364000         0.0    -3168000        -69.9     554784000
# 48  2023-11-15      214000         0.0      -58000        -21.3     230592472
# 49  2023-12-06      207000         0.0      -67800        -24.7      58288197
#
#     audiCnt  audiInten  audiChange   audiAcc  scrnCnt  showCnt multiMovieYn  \
# 0    290717     -59184       -16.9   3728850     1706     5793          NaN
# 1    262422     -64054       -19.6  12117201     1614     5444          NaN
# 2     58239      -6751       -10.4    626508      834     1671          NaN
# 3     49368     -14686       -22.9    772354      832     1611          NaN
# 4     28988      -1952        -6.3    365927      660      981          NaN
# 5     11586        190         1.7    332776      335      432          NaN
# 6     10704      -1268       -10.6     52400      357      419          NaN
# 7      8710       -524        -5.7    396137      187      263          NaN
# 8      6471         67         1.0     45294      207      248          NaN
# 9      3765       -164        -4.2     89597       95      127          NaN
# 10   290717     -59184       -16.9   3728850     1706     5793            N
# 11   262422     -64054       -19.6  12117201     1614     5444            N
# 12    58239      -6751       -10.4    626508      834     1671            N
# 13    49368     -14686       -22.9    772354      832     1611            N
# 14    28988      -1952        -6.3    365927      660      981            N
# 15    11586        190         1.7    332776      335      432            N
# 16    10704      -1268       -10.6     52400      357      419            N
# 17     3765       -164        -4.2     89597       95      127            N
# 18     3295       -626       -16.0    517836      132      157            N
# 19      540        -20        -3.6    225912       23       25            N
# 20     8710       -524        -5.7    396137      187      263            Y
# 21     6471         67         1.0     45294      207      248            Y
# 22     3001      -1659       -35.6     34196      200      270            Y
# 23     2534       -235        -8.5     39445       79      102            Y
# 24     1052        -28        -2.6     17008       30       33            Y
# 25      729       -181       -19.9     18551       20       23            Y
# 26      318        -29        -8.4   2009716       17       20            Y
# 27      294       -142       -32.6     51876       23       25            Y
# 28      294        294       100.0       512        4        4            Y
# 29      292         72        32.7     20951        1        3            Y
# 30    58239      -6751       -10.4    626508      834     1671          NaN
# 31    49368     -14686       -22.9    772354      832     1611          NaN
# 32    28988      -1952        -6.3    365927      660      981          NaN
# 33     8710       -524        -5.7    396137      187      263          NaN
# 34     6471         67         1.0     45294      207      248          NaN
# 35     3765       -164        -4.2     89597       95      127          NaN
# 36     3001      -1659       -35.6     34196      200      270          NaN
# 37     2534       -235        -8.5     39445       79      102          NaN
# 38     1052        -28        -2.6     17008       30       33          NaN
# 39      729       -181       -19.9     18551       20       23          NaN
# 40   290717     -59184       -16.9   3728850     1706     5793          NaN
# 41   262422     -64054       -19.6  12117201     1614     5444          NaN
# 42    11586        190         1.7    332776      335      432          NaN
# 43    10704      -1268       -10.6     52400      357      419          NaN
# 44     3295       -626       -16.0    517836      132      157          NaN
# 45      212        -17        -7.4    399787        9        9          NaN
# 46      192       -337       -63.7     33811        8        8          NaN
# 47       69       -144       -67.6     25099        8        8          NaN
# 48       31         -8       -20.5     27603        2        2          NaN
# 49       29        -19       -39.6      6717        3        3          NaN
#
#    repNationCd
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30           F
# 31           F
# 32           F
# 33           F
# 34           F
# 35           F
# 36           F
# 37           F
# 38           F
# 39           F
# 40           K
# 41           K
# 42           K
# 43           K
# 44           K
# 45           K
# 46           K
# 47           K
# 48           K
# 49           K
