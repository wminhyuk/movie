# %%
import pandas as pd
PATH = "~/data/movie_after/meta/meta.parquet"
df = pd.read_parquet(PATH)

# %%
df
# Out:
#       movieCd multiMovieYn repNationCd
# 0    19860125            Y         NaN
# 1    20124722            Y         NaN
# 2    20190324            N         NaN
# 3    20190324            N           K
# 4    20190324            N           K
# ..        ...          ...         ...
# 118  20236146            N           F
# 119  20236146          NaN           F
# 120  20236146            N           F
# 121  20236146          NaN           F
# 122  20236533            Y         NaN
#
# [123 rows x 3 columns]

# %%
movie_df = pd.read_parquet(f"/home/seominhyuk/data/movies/dailyboxoffice/dt=20240101")

# %%
movie_df
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd  \
# 0      1     1          0           OLD  20203702
# 1      2     2          0           OLD  20212866
# 2      3     3          0           OLD  20236146
# 3      4     4          0           OLD  20235735
# 4      5     5          0           OLD  20235596
# 5      6     6          1           OLD  20234673
# 6      7     7         -1           OLD  20235290
# 7      8     8          0           OLD  20234114
# 8      9     9          0           OLD  20236045
# 9     10    10          1           OLD  20235980
# 10     1     1          0           OLD  20203702
# 11     2     2          0           OLD  20212866
# 12     3     3          0           OLD  20236146
# 13     4     4          0           OLD  20235735
# 14     5     5          0           OLD  20235596
# 15     6     6          1           OLD  20234673
# 16     7     7         -1           OLD  20235290
# 17     8     8          0           OLD  20235980
# ...

# %%
df
# Out:
#       movieCd multiMovieYn repNationCd
# 0    19860125            Y         NaN
# 1    20124722            Y         NaN
# 2    20190324            N         NaN
# 3    20190324            N           K
# 4    20190324            N           K
# ..        ...          ...         ...
# 118  20236146            N           F
# 119  20236146          NaN           F
# 120  20236146            N           F
# 121  20236146          NaN           F
# 122  20236533            Y         NaN
#
# [123 rows x 3 columns]
