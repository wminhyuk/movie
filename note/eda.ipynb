# %%
import pandas as pd
PATH = "~/data/movies/dailyboxoffice/dt=20240101"
df = pd.read_parquet(PATH)
len(df)

df.groupby(['multiMovieYn', 'repNationCd'], dropna=False, observed=False) \
.size() \
.reset_index(name='count')
# Out:
#   multiMovieYn repNationCd  count
# 0            N           F      0
# 1            N           K      0
# 2            N         NaN     10
# 3            Y           F      0
# 4            Y           K      0
# 5            Y         NaN     10
# 6          NaN           F     10
# 7          NaN           K     10
# 8          NaN         NaN     10

# %%
len(df)
# Out:
# 50

# %%
print(df.sample(10))
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd  \
# 20     1     1          0           OLD  20234114
# 12     3     3          0           OLD  20236146
# 7      8     8          0           OLD  20234114
# 11     2     2          0           OLD  20212866
# 23     4     4          0           OLD  20233299
# 27     8     8          2           OLD  20124722
# 16     7     7         -1           OLD  20235290
# 21     2     2          0           OLD  20236045
# 49    10    10          3           OLD  20227525
# 6      7     7         -1           OLD  20235290
#
#                                  movieNm      openDt    salesAmt  salesShare  \
# 20                                    괴물  2023-11-29    92381680        37.0
# 12  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  2023-12-22   565417320         7.8
# 7                                     괴물  2023-11-29    92381680         1.2
# 11                                 서울의 봄  2023-11-22  2666429137        37.0
# ...

# %%
for _, row in df.iterrows():
    if pd.isna(row['multiMovieYn']):
        print(f"{row['movieCd']}")

# 출력
20203702
20212866
20236146
20235735
20235596
# Out:
# 20203702
# 20212866
# 20236146
# 20235735
# 20235596
# 20234673
# 20235290
# 20234114
# 20236045
# 20235980
# 20236146
# 20235735
# 20235596
# 20234114
# 20236045
# 20235980
# 20236080
# 20233299
# 20235923
# 20235693
# 20203702
# 20212866
# 20234673
# 20235290
# 20190324
# 20202247
# 20228560
# 20235697
# 20232077
# 20227525
# 20235596

# %%
r = df[df['movieCd'] == '20203702'][['movieCd', 'movieNm', 'multiMovieYn', 'repNationCd']]
# pdm add -dG note tabulate
print(r.to_markdown())
# Out:
# |    |   movieCd | movieNm           | multiMovieYn   | repNationCd   |
# |---:|----------:|:------------------|:---------------|:--------------|
# |  0 |  20203702 | 노량: 죽음의 바다 | nan            | nan           |
# | 10 |  20203702 | 노량: 죽음의 바다 | N              | nan           |
# | 40 |  20203702 | 노량: 죽음의 바다 | nan            | K             |

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 'movieCd'를 기준으로 그룹화하여, 각 그룹의 'multiMovieYn'과 'repNationCd' 컬럼을 처리
df_clean = df.groupby('movieCd', as_index=False).agg({
    'multiMovieYn': first_non_null,
    'repNationCd': first_non_null
})

# %%
print(df_clean)
# Out:
#      movieCd multiMovieYn repNationCd
# 0   19860125            Y         NaN
# 1   20124722            Y         NaN
# 2   20190324            N           K
# 3   20202247          NaN           K
# 4   20203702            N           K
# 5   20212866            N           K
# 6   20227525          NaN           K
# 7   20228560          NaN           K
# 8   20232077          NaN           K
# 9   20233299            Y           F
# 10  20234114            Y           F
# 11  20234664            Y         NaN
# 12  20234673            N           K
# 13  20235098            N         NaN
# 14  20235290            N           K
# 15  20235596            N           F
# 16  20235693            Y           F
# 17  20235697          NaN           K
# 18  20235735            N           F
# 19  20235923            Y           F
# 20  20235980            N           F
# 21  20236045            Y           F
# 22  20236080            Y           F
# 23  20236146            N           F
# ...

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 'movieCd'를 기준으로 그룹화하여, movieNm, multiMovieYn, repNationCd 컬럼을 처리
df_clean = df.groupby('movieCd', as_index=False).agg({
    'movieNm': first_non_null,
    'multiMovieYn': first_non_null,
    'repNationCd': first_non_null
})

# 결과 출력
print(df_clean)
# Out:
#      movieCd                               movieNm multiMovieYn repNationCd
# 0   19860125                                  쿼바디스            Y         NaN
# 1   20124722                             피아니스트의 전설            Y         NaN
# 2   20190324                                3일의 휴가            N           K
# 3   20202247                               싱글 인 서울          NaN           K
# 4   20203702                            노량: 죽음의 바다            N           K
# 5   20212866                                 서울의 봄            N           K
# 6   20227525                             교토에서 온 편지          NaN           K
# 7   20228560                                  너와 나          NaN           K
# 8   20232077                                어른 김장하          NaN           K
# 9   20233299                                  크레센도            Y           F
# 10  20234114                                    괴물            Y           F
# ...

# %%
ㅊ

# 결과 DataFrame을 마크다운 형식으로 출력
print(df_clean.to_markdown())
# Out:
# |    |   movieCd | openDt     | movieNm                                                       | multiMovieYn   | repNationCd   |
# |---:|----------:|:-----------|:--------------------------------------------------------------|:---------------|:--------------|
# |  0 |  19860125 | 1973-01-13 | 쿼바디스                                                      | Y              | nan           |
# |  1 |  20124722 | 2020-01-01 | 피아니스트의 전설                                             | Y              | nan           |
# |  2 |  20190324 | 2023-12-06 | 3일의 휴가                                                    | N              | K             |
# |  3 |  20202247 | 2023-11-29 | 싱글 인 서울                                                  | nan            | K             |
# |  4 |  20203702 | 2023-12-20 | 노량: 죽음의 바다                                             | N              | K             |
# ...

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 'movieCd'를 인덱스로 사용하여 그룹화 및 집계
df_clean = df.groupby('movieCd').agg({
    'movieNm': first_non_null,
    'multiMovieYn': first_non_null,
    'repNationCd': first_non_null
})

# 결과 DataFrame을 마크다운 형식으로 인덱스와 함께 출력
print(df_clean.to_markdown(index=True))
# Out:
# |   movieCd | movieNm                                                       | multiMovieYn   | repNationCd   |
# |----------:|:--------------------------------------------------------------|:---------------|:--------------|
# |  19860125 | 쿼바디스                                                      | Y              | nan           |
# |  20124722 | 피아니스트의 전설                                             | Y              | nan           |
# |  20190324 | 3일의 휴가                                                    | N              | K             |
# |  20202247 | 싱글 인 서울                                                  | nan            | K             |
# |  20203702 | 노량: 죽음의 바다                                             | N              | K             |
# |  20212866 | 서울의 봄                                                     | N              | K             |
# |  20227525 | 교토에서 온 편지                                              | nan            | K             |
# ...

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 'movieCd'를 인덱스로 사용하여 그룹화 및 집계 수행
df_clean = df.groupby('movieCd').agg({
    'movieNm': first_non_null,
    'multiMovieYn': first_non_null,
    'repNationCd': first_non_null
})

# 결과 DataFrame을 인덱스 형식(기본 텍스트 출력)으로 출력
print(df_clean.to_string(index=True))
# Out:
#                                        movieNm multiMovieYn repNationCd
# movieCd
# 19860125                                  쿼바디스            Y         NaN
# 20124722                             피아니스트의 전설            Y         NaN
# 20190324                                3일의 휴가            N           K
# 20202247                               싱글 인 서울          NaN           K
# 20203702                            노량: 죽음의 바다            N           K
# 20212866                                 서울의 봄            N           K
# 20227525                             교토에서 온 편지          NaN           K
# 20228560                                  너와 나          NaN           K
# 20232077                                어른 김장하          NaN           K
# 20233299                                  크레센도            Y           F
# 20234114                                    괴물            Y           F
# 20234664                        그대들은 어떻게 살 것인가            Y         NaN
# ...

# %%
# 예시로 사용할 get_counts 함수 (실제 로직에 맞게 수정하세요)
def get_counts(group, include_groups=False):
    # 예: 각 그룹의 행 수를 계산하여 'count' 컬럼에 저장하는 경우
    return pd.Series({'count': len(group)})

# df_grouped_nm 데이터프레임이 이미 존재한다고 가정합니다.
# movieNm을 기준으로 그룹화한 후 get_counts 함수를 적용하고, 인덱스를 재설정합니다.
result_df = df_grouped_nm.groupby('movieNm', group_keys=False) \
    .apply(get_counts, include_groups=False) \
    .reset_index()

# print() 함수를 사용하여 기본 출력 형식으로 결과 출력
print(result_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 8
#       4     return pd.Series({'count': len(group)})
#       6 # df_grouped_nm 데이터프레임이 이미 존재한다고 가정합니다.
#       7 # movieNm을 기준으로 그룹화한 후 get_counts 함수를 적용하고, 인덱스를 재설정합니다.
# ----> 8 result_df = df_grouped_nm.groupby('movieNm', group_keys=False) \
#       9     .apply(get_counts, include_groups=False) \
#      10     .reset_index()
#      12 # print() 함수를 사용하여 기본 출력 형식으로 결과 출력
#      13 print(result_df)
#
# NameError: name 'df_grouped_nm' is not defined

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 'movieCd'를 인덱스로 사용하여 그룹화 및 집계 후, reset_index()를 적용
df_clean = df.groupby('movieCd').agg({
    'movieNm': first_non_null,
    'multiMovieYn': first_non_null,
    'repNationCd': first_non_null
}).reset_index()

# reset_index() 후의 결과 DataFrame을 마크다운 형식으로 출력
print(df_clean.to_markdown(index=False))
# Out:
# |   movieCd | movieNm                                                       | multiMovieYn   | repNationCd   |
# |----------:|:--------------------------------------------------------------|:---------------|:--------------|
# |  19860125 | 쿼바디스                                                      | Y              | nan           |
# |  20124722 | 피아니스트의 전설                                             | Y              | nan           |
# |  20190324 | 3일의 휴가                                                    | N              | K             |
# |  20202247 | 싱글 인 서울                                                  | nan            | K             |
# |  20203702 | 노량: 죽음의 바다                                             | N              | K             |
# |  20212866 | 서울의 봄                                                     | N              | K             |
# |  20227525 | 교토에서 온 편지                                              | nan            | K             |
# ...

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 'movieCd'를 인덱스로 사용하여 그룹화 및 집계 후 reset_index()를 적용
df_clean = df.groupby('movieCd').agg({
    'movieNm': first_non_null,
    'multiMovieYn': first_non_null,
    'repNationCd': first_non_null
}).reset_index()

# 결과 DataFrame을 기본 출력 형식 그대로 출력
print(df_clean)
# Out:
#      movieCd                               movieNm multiMovieYn repNationCd
# 0   19860125                                  쿼바디스            Y         NaN
# 1   20124722                             피아니스트의 전설            Y         NaN
# 2   20190324                                3일의 휴가            N           K
# 3   20202247                               싱글 인 서울          NaN           K
# 4   20203702                            노량: 죽음의 바다            N           K
# 5   20212866                                 서울의 봄            N           K
# 6   20227525                             교토에서 온 편지          NaN           K
# 7   20228560                                  너와 나          NaN           K
# 8   20232077                                어른 김장하          NaN           K
# 9   20233299                                  크레센도            Y           F
# 10  20234114                                    괴물            Y           F
# ...

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 'movieCd'를 인덱스로 사용하여 그룹화 및 집계 후 reset_index()를 적용
df_clean = df.groupby('movieCd').agg({
    'movieNm': first_non_null,
    'multiMovieYn': first_non_null,
    'repNationCd': first_non_null
}).reset_index()

# 1) 셀 마지막에 df_clean만 적어도 자동으로 예쁜 표로 출력됩니다.
df_clean
# Out:
#      movieCd                               movieNm multiMovieYn repNationCd
# 0   19860125                                  쿼바디스            Y         NaN
# 1   20124722                             피아니스트의 전설            Y         NaN
# 2   20190324                                3일의 휴가            N           K
# 3   20202247                               싱글 인 서울          NaN           K
# 4   20203702                            노량: 죽음의 바다            N           K
# 5   20212866                                 서울의 봄            N           K
# 6   20227525                             교토에서 온 편지          NaN           K
# 7   20228560                                  너와 나          NaN           K
# 8   20232077                                어른 김장하          NaN           K
# 9   20233299                                  크레센도            Y           F
# 10  20234114                                    괴물            Y           F
# ...

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 'movieCd'를 인덱스로 사용하여 그룹화 및 집계 후 reset_index()를 적용
df_clean = df.groupby('movieCd').agg({
    'movieNm': first_non_null,
    'multiMovieYn': first_non_null,
    'repNationCd': first_non_null
}).reset_index()

df_clean
# Out:
#      movieCd                               movieNm multiMovieYn repNationCd
# 0   19860125                                  쿼바디스            Y         NaN
# 1   20124722                             피아니스트의 전설            Y         NaN
# 2   20190324                                3일의 휴가            N           K
# 3   20202247                               싱글 인 서울          NaN           K
# 4   20203702                            노량: 죽음의 바다            N           K
# 5   20212866                                 서울의 봄            N           K
# 6   20227525                             교토에서 온 편지          NaN           K
# 7   20228560                                  너와 나          NaN           K
# 8   20232077                                어른 김장하          NaN           K
# 9   20233299                                  크레센도            Y           F
# 10  20234114                                    괴물            Y           F
# ...

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 'movieCd'를 기준으로 그룹화하여, movieNm, multiMovieYn, repNationCd 컬럼에 대해 집계 수행
df_clean = df.groupby('movieCd', as_index=False).agg({
    'openDt': first_non_null,
    'movieNm': first_non_null,
    'multiMovieYn': first_non_null,
    'repNationCd': first_non_null
})
df_clean
# Out:
#      movieCd      openDt                               movieNm multiMovieYn  \
# 0   19860125  1973-01-13                                  쿼바디스            Y
# 1   20124722  2020-01-01                             피아니스트의 전설            Y
# 2   20190324  2023-12-06                                3일의 휴가            N
# 3   20202247  2023-11-29                               싱글 인 서울          NaN
# 4   20203702  2023-12-20                            노량: 죽음의 바다            N
# 5   20212866  2023-11-22                                 서울의 봄            N
# 6   20227525  2023-12-06                             교토에서 온 편지          NaN
# 7   20228560  2023-10-25                                  너와 나          NaN
# 8   20232077  2023-11-15                                어른 김장하          NaN
# 9   20233299  2023-12-20                                  크레센도            Y
# 10  20234114  2023-11-29                                    괴물            Y
# ...

# %%
unique_movie_codes = df['movieCd'].unique()
print(unique_movie_codes)
print(len(unique_movie_codes))
# Out:
# ['20203702' '20212866' '20236146' '20235735' '20235596' '20234673'
#  '20235290' '20234114' '20236045' '20235980' '20190324' '20235098'
#  '20236080' '20233299' '20235923' '20235693' '20234664' '20124722'
#  '20236533' '19860125' '20202247' '20228560' '20235697' '20232077'
#  '20227525']
# 25

# %%
# 2-1. multiMovieYn 컬럼의 NaN 건수
nan_multiMovieYn = df['multiMovieYn'].isna().sum()

# 2-2. repNationCd 컬럼의 NaN 건수
nan_repNationCd = df['repNationCd'].isna().sum()

# 2-3. multiMovieYn 과 repNationCd 두 컬럼이 동시에 NaN인 건수
nan_both = df[df['multiMovieYn'].isna() & df['repNationCd'].isna()].shape[0]

print("multiMovieYn의 NaN 건수:", nan_multiMovieYn)
print("repNationCd의 NaN 건수:", nan_repNationCd)
print("multiMovieYn과 repNationCd가 동시에 NaN인 건수:", nan_both)
# Out:
# multiMovieYn의 NaN 건수: 30
# repNationCd의 NaN 건수: 30
# multiMovieYn과 repNationCd가 동시에 NaN인 건수: 10

# %%
print(df)
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd  \
# 0      1     1          0           OLD  20203702
# 1      2     2          0           OLD  20212866
# 2      3     3          0           OLD  20236146
# 3      4     4          0           OLD  20235735
# 4      5     5          0           OLD  20235596
# 5      6     6          1           OLD  20234673
# 6      7     7         -1           OLD  20235290
# 7      8     8          0           OLD  20234114
# 8      9     9          0           OLD  20236045
# 9     10    10          1           OLD  20235980
# 10     1     1          0           OLD  20203702
# 11     2     2          0           OLD  20212866
# 12     3     3          0           OLD  20236146
# 13     4     4          0           OLD  20235735
# 14     5     5          0           OLD  20235596
# 15     6     6          1           OLD  20234673
# 16     7     7         -1           OLD  20235290
# 17     8     8          0           OLD  20235980
# ...

# %%
import pandas as pd

# 1) audiCnt 기준 내림차순 정렬 후, movieCd 중복 제거(가장 큰 audiCnt 행만 남김)
df_unique = (
    df.sort_values('audiCnt', ascending=False)
      .drop_duplicates(subset='movieCd', keep='first')
      .reset_index(drop=True)
)

# 2) 기존 rnum, rank 컬럼 제거
df_unique.drop(columns=['rnum', 'rank'], inplace=True)

# 3) audiCnt 내림차순 순서에 따라 새 rnum, rank 컬럼 생성
#    (위에서부터 1, 2, 3... 순으로 매깁니다)
df_unique['rnum'] = df_unique.index + 1
df_unique['rank'] = df_unique.index + 1

# 결과 확인
print(df_unique)
# Out:
#     rankInten rankOldAndNew   movieCd                               movieNm  \
# 0           0           OLD  20203702                            노량: 죽음의 바다
# 1           0           OLD  20212866                                 서울의 봄
# 2           0           OLD  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~
# 3           0           OLD  20235735                          아쿠아맨과 로스트 킹덤
# 4           0           OLD  20235596                            트롤: 밴드 투게더
# 5           1           OLD  20234673                      뽀로로 극장판 슈퍼스타 대모험
# 6          -1           OLD  20235290                             도티와 영원의 탑
# 7           0           OLD  20234114                                    괴물
# 8           0           OLD  20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!
# 9           1           OLD  20235980                             말하고 싶은 비밀
# 10          0           OLD  20190324                                3일의 휴가
# ...

# %%
import pandas as pd

# 1) audiCnt 기준 내림차순 정렬 후, movieCd 중복 제거(가장 큰 audiCnt 행만 남김)
df_unique = (
    df.sort_values('audiCnt', ascending=False)
      .drop_duplicates(subset='movieCd', keep='first')
      .reset_index(drop=True)
)

# 2) 기존 rnum, rank 컬럼 제거 (존재하지 않더라도 에러 무시)
df_unique.drop(columns=['rnum', 'rank'], errors='ignore', inplace=True)

# 3) 새 rnum, rank 컬럼 생성 (1부터 시작)
df_unique['rnum'] = df_unique.index + 1
df_unique['rank'] = df_unique.index + 1

# 4) 원하는 컬럼만 지정한 순서대로 추출
df_result = df_unique[['movieCd', 'movieNm', 'openDt', 'rnum', 'rank']]

# 결과 출력
print(df_result)
# Out:
#      movieCd                               movieNm      openDt  rnum  rank
# 0   20203702                            노량: 죽음의 바다  2023-12-20     1     1
# 1   20212866                                 서울의 봄  2023-11-22     2     2
# 2   20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  2023-12-22     3     3
# 3   20235735                          아쿠아맨과 로스트 킹덤  2023-12-20     4     4
# 4   20235596                            트롤: 밴드 투게더  2023-12-20     5     5
# 5   20234673                      뽀로로 극장판 슈퍼스타 대모험  2023-12-13     6     6
# 6   20235290                             도티와 영원의 탑  2023-12-27     7     7
# 7   20234114                                    괴물  2023-11-29     8     8
# 8   20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!  2023-12-27     9     9
# 9   20235980                             말하고 싶은 비밀  2023-12-13    10    10
# 10  20190324                                3일의 휴가  2023-12-06    11    11
# ...

# %%
import pandas as pd

# 1) audiCnt 기준 내림차순 정렬 후, movieCd 중복 제거 (가장 큰 audiCnt 행만 남김)
df_unique = (
    df.sort_values('audiCnt', ascending=False)
      .drop_duplicates(subset='movieCd', keep='first')
      .reset_index(drop=True)
)

# 2) 기존 rnum, rank 컬럼 제거 (존재하지 않아도 에러 무시)
df_unique.drop(columns=['rnum', 'rank'], errors='ignore', inplace=True)

# 3) 새 rnum, rank 컬럼 생성 (1부터 시작)
df_unique['rnum'] = df_unique.index + 1
df_unique['rank'] = df_unique.index + 1

# 4) 원하는 컬럼만 지정한 순서대로 추출
df_result = df_unique[['movieCd', 'movieNm', 'openDt', 'rnum', 'rank']]

# 5) 결과 DataFrame을 마크다운 형식으로 출력
print(df_result.to_markdown(index=False))
# Out:
# |   movieCd | movieNm                                                       | openDt     |   rnum |   rank |
# |----------:|:--------------------------------------------------------------|:-----------|-------:|-------:|
# |  20203702 | 노량: 죽음의 바다                                             | 2023-12-20 |      1 |      1 |
# |  20212866 | 서울의 봄                                                     | 2023-11-22 |      2 |      2 |
# |  20236146 | 신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~ | 2023-12-22 |      3 |      3 |
# |  20235735 | 아쿠아맨과 로스트 킹덤                                        | 2023-12-20 |      4 |      4 |
# |  20235596 | 트롤: 밴드 투게더                                             | 2023-12-20 |      5 |      5 |
# |  20234673 | 뽀로로 극장판 슈퍼스타 대모험                                 | 2023-12-13 |      6 |      6 |
# |  20235290 | 도티와 영원의 탑                                              | 2023-12-27 |      7 |      7 |
# ...

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 1) audiCnt 기준 내림차순 정렬 후, movieCd 중복 제거 (가장 큰 audiCnt 행만 남김)
df_unique = (
    df.sort_values('audiCnt', ascending=False)
      .drop_duplicates(subset='movieCd', keep='first')
      .reset_index(drop=True)
)

# 2) 기존 rnum, rank 컬럼 제거 (존재하지 않아도 에러 무시)
df_unique.drop(columns=['rnum', 'rank'], errors='ignore', inplace=True)

# 3) 새 rnum, rank 컬럼 생성 (1부터 시작)
df_unique['rnum'] = df_unique.index + 1
df_unique['rank'] = df_unique.index + 1

# 4) 원하는 컬럼만 지정한 순서대로 추출: movieCd, movieNm, openDt, rnum, rank
df_result = df_unique[['movieCd', 'movieNm', 'openDt', 'rnum', 'rank']]

# 전체 결과를 마크다운 형식으로 출력
print("전체 결과:")
print(df_result.to_markdown(index=False))

# head 3 출력
print("\nHead 3:")
print(df_result.head(3).to_markdown(index=False))

# tail 3 출력
print("\nTail 3:")
print(df_result.tail(3).to_markdown(index=False))

# 'movieCd' 컬럼만 별도로 출력 (DataFrame 형태로 변환하여 마크다운 출력)
print("\n'movieCd' 컬럼:")
print(df_result[['movieCd']].to_markdown(index=False))
# Out:
# 전체 결과:
# |   movieCd | movieNm                                                       | openDt     |   rnum |   rank |
# |----------:|:--------------------------------------------------------------|:-----------|-------:|-------:|
# |  20203702 | 노량: 죽음의 바다                                             | 2023-12-20 |      1 |      1 |
# |  20212866 | 서울의 봄                                                     | 2023-11-22 |      2 |      2 |
# |  20236146 | 신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~ | 2023-12-22 |      3 |      3 |
# |  20235735 | 아쿠아맨과 로스트 킹덤                                        | 2023-12-20 |      4 |      4 |
# |  20235596 | 트롤: 밴드 투게더                                             | 2023-12-20 |      5 |      5 |
# |  20234673 | 뽀로로 극장판 슈퍼스타 대모험                                 | 2023-12-13 |      6 |      6 |
# |  20235290 | 도티와 영원의 탑                                              | 2023-12-27 |      7 |      7 |
# ...

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 1) audiCnt 기준 내림차순 정렬 후, movieCd 중복 제거 (가장 큰 audiCnt 행만 남김)
df_unique = (
    df.sort_values('audiCnt', ascending=False)
      .drop_duplicates(subset='movieCd', keep='first')
      .reset_index(drop=True)
)

# 2) 기존 rnum, rank 컬럼 제거 (존재하지 않아도 에러 무시)
df_unique.drop(columns=['rnum', 'rank'], errors='ignore', inplace=True)

# 3) 새 rnum, rank 컬럼 생성 (1부터 시작)
df_unique['rnum'] = df_unique.index + 1
df_unique['rank'] = df_unique.index + 1

# 4) 원하는 컬럼만 지정한 순서대로 추출: movieCd, movieNm, openDt, rnum, rank
df_result = df_unique[['movieCd', 'movieNm', 'openDt', 'audiCnt', 'rnum', 'rank']]

# 전체 결과를 마크다운 형식으로 출력
print("전체 결과:")
print(df_result.to_markdown(index=False))


# 상위 3개 행의 'movieNm' 컬럼만 출력
print("Head 3 (movieNm only):")
print(df_result[['movieNm']].head(3).to_markdown(index=False))

# 하위 3개 행의 'movieNm' 컬럼만 출력
print("\nTail 3 (movieNm only):")
print(df_result[['movieNm']].tail(3).to_markdown(index=False))
# Out:
# 전체 결과:
# |   movieCd | movieNm                                                       | openDt     |   audiCnt |   rnum |   rank |
# |----------:|:--------------------------------------------------------------|:-----------|----------:|-------:|-------:|
# |  20203702 | 노량: 죽음의 바다                                             | 2023-12-20 |    290717 |      1 |      1 |
# |  20212866 | 서울의 봄                                                     | 2023-11-22 |    262422 |      2 |      2 |
# |  20236146 | 신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~ | 2023-12-22 |     58239 |      3 |      3 |
# |  20235735 | 아쿠아맨과 로스트 킹덤                                        | 2023-12-20 |     49368 |      4 |      4 |
# |  20235596 | 트롤: 밴드 투게더                                             | 2023-12-20 |     28988 |      5 |      5 |
# |  20234673 | 뽀로로 극장판 슈퍼스타 대모험                                 | 2023-12-13 |     11586 |      6 |      6 |
# ...

# %%
import numpy as np
import pandas as pd

# NaN이 아닌 첫 번째 값을 반환하는 함수 정의
def first_non_null(series):
    valid = series.dropna()
    return valid.iloc[0] if len(valid) > 0 else np.nan

# 1) audiCnt 기준 내림차순 정렬 후, movieCd 중복 제거 (가장 큰 audiCnt 행만 남김)
df_unique = (
    df.sort_values('audiCnt', ascending=False)
      .drop_duplicates(subset='movieCd', keep='first')
      .reset_index(drop=True)
)

# 2) 기존 rnum, rank 컬럼 제거 (존재하지 않아도 에러 무시)
df_unique.drop(columns=['rnum', 'rank'], errors='ignore', inplace=True)

# 3) 새 rnum, rank 컬럼 생성 (1부터 시작)
df_unique['rnum'] = df_unique.index + 1
df_unique['rank'] = df_unique.index + 1

# 4) 원하는 컬럼만 지정한 순서대로 추출: movieCd, movieNm, openDt, rnum, rank
df_result = df_unique[['movieCd', 'movieNm', 'openDt', 'audiCnt', 'rnum', 'rank']]

# 전체 결과를 마크다운 형식으로 출력
print("전체 결과:")
print(df_result.to_markdown(index=False))

# head 3 출력
print("\nHead 3:")
print(df_result.head(3).to_markdown(index=False))

# tail 3 출력
print("\nTail 3:")
print(df_result.tail(3).to_markdown(index=False))
# Out:
# 전체 결과:
# |   movieCd | movieNm                                                       | openDt     |   audiCnt |   rnum |   rank |
# |----------:|:--------------------------------------------------------------|:-----------|----------:|-------:|-------:|
# |  20203702 | 노량: 죽음의 바다                                             | 2023-12-20 |    290717 |      1 |      1 |
# |  20212866 | 서울의 봄                                                     | 2023-11-22 |    262422 |      2 |      2 |
# |  20236146 | 신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~ | 2023-12-22 |     58239 |      3 |      3 |
# |  20235735 | 아쿠아맨과 로스트 킹덤                                        | 2023-12-20 |     49368 |      4 |      4 |
# |  20235596 | 트롤: 밴드 투게더                                             | 2023-12-20 |     28988 |      5 |      5 |
# |  20234673 | 뽀로로 극장판 슈퍼스타 대모험                                 | 2023-12-13 |     11586 |      6 |      6 |
# ...
